# %% [markdown]
# <a href="https://colab.research.google.com/github/sai-23may/Text-To-Image/blob/main/text_to_image_synthesizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mounting Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Necessary imports
import glob
import pandas as pd
import urllib.request
import imageio
import os
import numpy as np

from urllib.request import urlopen

# %%
# Load Glove Function
def loadGloveModel(gloveFile):
    print("Loading Glove Model")
    f = open(gloveFile,'r',encoding="utf8")
    model = {}
    for line in f:
        try:
            splitLine = line.split()
            word = splitLine[0]
            embedding = np.array([float(val) for val in splitLine[1:]])
            model[word] = embedding
        except:
            print(word)
    print("Done.",len(model)," words loaded!")
    return model

# %%
glove_embeddings = loadGloveModel("/content/drive/MyDrive/package stuff/Package/embeddings/glove.6B.300d.txt")
# Out:
# Loading Glove Model
# Done. 400000  words loaded!

# %%
# Setting up the paths
train_data_path = "/content/drive/MyDrive/package stuff/Package/flowers_data/flowers"
train_images_path = "/content/drive/MyDrive/package stuff/Package/flowers_data/flowers/images/jpg/jpg"
train_captions_path = "/content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10"

# %% [markdown]
# The following packages will be used to implement a basic GAN system in Python/Keras.

# %%
# Imports
import tensorflow as tf
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense, Concatenate 
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D, Conv2DTranspose
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras import initializers
from sklearn.metrics import mean_squared_error

import numpy as np
from PIL import Image
from tqdm import tqdm
import os 
import time
import matplotlib.pyplot as plt

# %%
# Formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %%
# Generation resolution - Must be square 
# Training data is also scaled to this.
GENERATE_RES = 4 # Generation resolution factor 
# (1=32, 2=64, 3=96, 4=128, etc.)
GENERATE_SQUARE = 32 * GENERATE_RES # rows/cols (should be square)
IMAGE_CHANNELS = 3

# Preview image 
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 16

# Size vector to generate images from
SEED_SIZE = 100
EMBEDDING_SIZE = 300

# Configuration
DATA_PATH = train_images_path
MODEL_PATH = "/content/drive/MyDrive/package stuff/Package/flowers_data/flowers/model"
EPOCHS = 50
BATCH_SIZE = 64
BUFFER_SIZE = 4000

print(f"Will generate {GENERATE_SQUARE}px square images.")
# Out:
# Will generate 128px square images.

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# Next we will load and preprocess the images.  This can take awhile.  Google CoLab took around an hour to process.  Because of this we store the processed file as a binary.  This way we can simply reload the processed training data and quickly use it.  It is most efficient to only perform this operation once.  The dimensions of the image are encoded into the filename of the binary file because we need to regenerate it if these change.

# %%
# Image set has 8,188 images.  Can take over an hour 
# for initial preprocessing.
# Because of this time needed, save a Numpy preprocessed file.

training_binary_path = os.path.join("/content/drive/MyDrive/package stuff/Package/flowers_data/flowers/images/npy64",
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}_')

start = time.time()
print("Loading training images...")

training_data = []
flowers_path = sorted(os.listdir(DATA_PATH))
print(flowers_path)
for filename in range(len(flowers_path)):
    path = os.path.join(DATA_PATH,flowers_path[filename])
    # print(path)
    try:
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      channel = np.asarray(image).shape[2]
      if channel == 3:
        training_data.append(np.asarray(image))
    except KeyboardInterrupt:
        print("Keyboard Interrup by me...")
        break
    except:
      pass
    if len(training_data) == 100:
      training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
                GENERATE_SQUARE,IMAGE_CHANNELS))
      training_data = training_data.astype(np.float32)
      #Normalizing the input
      training_data = training_data / 127.5 - 1.

      print("Saving training image " + str(100000 + filename) + ".npy")
      np.save(training_binary_path + str(100000 + filename) + ".npy",training_data)
      elapsed = time.time()-start
      print (f'Image preprocess time: {hms_string(elapsed)}')
      training_data = []
print("Complete")
# Out:
# Loading training images...
# ['image_00001.jpg', 'image_00002.jpg', 'image_00003.jpg', 'image_00004.jpg', 'image_00005.jpg', 'image_00006.jpg', 'image_00007.jpg', 'image_00008.jpg', 'image_00009.jpg', 'image_00010.jpg', 'image_00011.jpg', 'image_00012.jpg', 'image_00013.jpg', 'image_00014.jpg', 'image_00015.jpg', 'image_00016.jpg', 'image_00017.jpg', 'image_00018.jpg', 'image_00019.jpg', 'image_00020.jpg', 'image_00021.jpg', 'image_00022.jpg', 'image_00023.jpg', 'image_00024.jpg', 'image_00025.jpg', 'image_00026.jpg', 'image_00027.jpg', 'image_00028.jpg', 'image_00
path = "/content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10"

l = []
ps = {}
for root, dirs, files in os.walk("/content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10"):
    for file in files:
        if file.endswith(".txt"):
             #print(file)
             l.append(file)
             ps[file] = os.path.join(root, file)

text_files = sorted(l)
captions = []
caption_embeddings = np.zeros((len(text_files),300),dtype=np.float32)
for filename in range(len(text_files)):
    path = ps[text_files[filename]]
    print(path)
    f = open(path,'r')
    data = f.read()
    data = data.split("\n")
    f.close()
    for d in range(1):
      x = data[d].lower()
      #x = x.replace(" ","")
      captions.append(x)
      count = 0
      for t in x:
        try:
          caption_embeddings[filename] += glove_embeddings[t]
          count += 1
        except:
          print(t)
          pass
      caption_embeddings[filename] /= count
    if filename %100 == 0:
      print("-------------Files completed:",filename)
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00098/image_07818.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00098/image_07819.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00098/image_07820.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00098/image_07821.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00098/image_07822.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00098/image_07823.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00098/image_07824.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00098/image_07825.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00098/image_07826.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00098/image_07827.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00098/image_07828.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00098/image_07829.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00098/image_07830.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00098/image_07831.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00098/image_07832.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07833.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07834.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07835.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07836.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07837.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07838.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07839.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07840.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07841.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07842.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07843.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07844.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07845.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07846.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07847.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07848.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07849.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07850.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07851.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07852.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07853.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07854.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07855.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07856.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07857.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07858.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07859.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07860.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07861.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07862.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07863.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07864.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07865.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07866.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07867.txt
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07868.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07869.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07870.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07871.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07872.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07873.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07874.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07875.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07876.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07877.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07878.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07879.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07880.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07881.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07882.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07883.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07884.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07885.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07886.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07887.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07888.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07889.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07890.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07891.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_07892.txt
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07893.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07894.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07895.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07896.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07897.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07898.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07899.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07900.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07901.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -------------Files completed: 7900
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07902.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07903.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07904.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07905.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07906.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07907.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07908.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07909.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07910.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07911.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07912.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07913.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07914.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07915.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07916.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07917.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07918.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07919.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07920.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07921.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07922.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07923.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07924.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07925.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07926.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07927.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07928.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07929.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07930.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07931.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07932.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07933.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07934.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07935.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07936.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07937.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07938.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07939.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07940.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00100/image_07941.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07942.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07943.txt
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07944.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07945.txt
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07946.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07947.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07948.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07949.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07950.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07951.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07952.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07953.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07954.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07955.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07956.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07957.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07958.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07959.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07960.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07961.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07962.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07963.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07964.txt
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07965.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07966.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07967.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07968.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07969.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07970.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07971.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07972.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07973.txt
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07974.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07975.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07976.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07977.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07978.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07979.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07980.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07981.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07982.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07983.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07984.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07985.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07986.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07987.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07988.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07989.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07990.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07991.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07992.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07993.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07994.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07995.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07996.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07997.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07998.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00101/image_07999.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08000.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08001.txt
#
#
#
#
#
#
#
#
#
# -------------Files completed: 8000
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08002.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08003.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08004.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08005.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08006.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08007.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08008.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08009.txt
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08010.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08011.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08012.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08013.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08014.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08015.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08016.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08017.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08018.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08019.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08020.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08021.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08022.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08023.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08024.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08025.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08026.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08027.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08028.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08029.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08030.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08031.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08032.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08033.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08034.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08035.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08036.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08037.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08038.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08039.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08040.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08041.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08042.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08043.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08044.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08045.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08046.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00102/image_08047.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00024/image_08048.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00024/image_08049.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00024/image_08050.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00024/image_08051.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00024/image_08052.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00024/image_08053.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00091/image_08054.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00091/image_08055.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00091/image_08056.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00091/image_08057.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00091/image_08058.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00091/image_08059.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00091/image_08060.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00091/image_08061.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_08062.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_08063.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00099/image_08064.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00031/image_08065.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00031/image_08066.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00031/image_08067.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00031/image_08068.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00031/image_08069.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00031/image_08070.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00031/image_08071.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00031/image_08072.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00031/image_08073.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00031/image_08074.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00031/image_08075.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00031/image_08076.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00031/image_08077.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00067/image_08078.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00067/image_08079.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00039/image_08080.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00039/image_08081.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00088/image_08082.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00088/image_08083.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00035/image_08084.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00035/image_08085.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00035/image_08086.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00035/image_08087.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00035/image_08088.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00071/image_08089.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00010/image_08090.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00010/image_08091.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00010/image_08092.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00010/image_08093.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00010/image_08094.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00010/image_08095.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00010/image_08096.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00010/image_08097.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00045/image_08098.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00007/image_08099.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00007/image_08100.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00007/image_08101.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -------------Files completed: 8100
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00007/image_08102.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00007/image_08103.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00007/image_08104.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00006/image_08105.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00006/image_08106.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00006/image_08107.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00006/image_08108.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00006/image_08109.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00006/image_08110.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00006/image_08111.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00093/image_08112.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00093/image_08113.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00093/image_08114.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00093/image_08115.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00093/image_08116.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00093/image_08117.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08118.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08119.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08120.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08121.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08122.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08123.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08124.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08125.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08126.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08127.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08128.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08129.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08130.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08131.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08132.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08133.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08134.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08135.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08136.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08137.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08138.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08139.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08140.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08141.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08142.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08143.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08144.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08145.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08146.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08147.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08148.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08149.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00057/image_08150.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08151.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08152.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08153.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08154.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08155.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08156.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08157.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08158.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08159.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08160.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08161.txt
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08162.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08163.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08164.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08165.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08166.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08167.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08168.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08169.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08170.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08171.txt
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08172.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08173.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08174.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08175.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08176.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08177.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08178.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08179.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08180.txt
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08181.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08182.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08183.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08184.txt
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08185.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08186.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08187.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08188.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
# /content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/class_00062/image_08189.txt

# %%
# saving the caption embeddings numpy
#embedding_binary_path = os.path.join('/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/images/embedding_npy',
#        f'embedding_data_character.npy')
# print("Saving captions embeddings binary...")
# np.save(embedding_binary_path,caption_embeddings)

# %%
# saving the caption embeddings numpy
embedding_binary_path = os.path.join('/content/drive/MyDrive/package stuff/Package/flowers_data/flowers/images/embedding_npy',
        f'embedding_data.npy')
print("Saving captions embeddings binary...")
np.save(embedding_binary_path,caption_embeddings)
# Out:
# Saving captions embeddings binary...

# %%
# Creating a dataframe to store the captions
df_captions = pd.DataFrame([])
df_captions['captions'] = captions[:len(final_images)]

# %%
df_captions.head()
# Out:
#                                             captions
# 0  prominent purple stigma,petals are white inc olor
# 1  this flower is blue and green in color, with p...
# 2  outer petals are green in color and klarger,in...
# 3  there are several shapes, sizes, and colors of...
# 4  the stamen are towering over the stigma which ...

# %%
captions[:10]
# Out:
# ['prominent purple stigma,petals are white inc olor',
#  'this flower is blue and green in color, with petals that are oval shaped.',
#  'outer petals are green in color and klarger,inner petals are needle shaped',
#  'there are several shapes, sizes, and colors of petals on this complex flower.',
#  'the stamen are towering over the stigma which cannot be seen.',
#  'this flower is white and purple in color, with petals that are oval shaped.',
#  'the petals of this flower are green with a long stigma',
#  'the blossom has a layer of rounded purple and white petals topped by a layer of fringed purple petals.',
#  'this flower is purple and yellow in color, with petals that are oval shaped.',
#  'the petals on this flower are white with an elaborate pistil.']

# %%
df_captions.to_csv("/content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/captions.csv",index=None)

# %% [markdown]
# ## Loading and combining numpys

# %%
embedding_binary_path = os.path.join('/content/drive/MyDrive/package stuff/Package/flowers_data/flowers/images/embedding_npy',
        f'embedding_data.npy')

# %%
caption_embeddings = np.load(embedding_binary_path)

# %%
print(caption_embeddings)
# Out:
# [[-0.2877301  -0.00107474 -0.2072907  ... -0.53047097 -0.07935404
#    0.16945915]
#  [-0.26723632  0.03717088 -0.30101988 ... -0.54951364 -0.09020615
#    0.14092845]
#  [-0.3756713   0.02952076 -0.30324548 ... -0.56901705 -0.23083352
#    0.06800084]
#  ...
#  [-0.25845718  0.04322989 -0.31873155 ... -0.53846526 -0.02812552
#    0.1592929 ]
#  [-0.28574035  0.02204715 -0.30363196 ... -0.5614028  -0.06559128
#    0.1988871 ]
#  [-0.29051405  0.03127474 -0.36992636 ... -0.5526128  -0.05409274
#    0.11360314]]

# %%
caption_embeddings.shape
# Out:
# (8189, 300)

# %%
image_binary_path = "/content/drive/MyDrive/package stuff/Package/flowers_data/flowers/images/npy64"
images = os.listdir(image_binary_path)

# %%
images[-1]
# Out:
# 'training_data_64_64_108099.npy'

# %%
# Creating a list of all the preprocessed images
final_images = np.load(image_binary_path +"/"+ images[0])
for i in images[1:]:
  print(i)
  try:
    final_images = np.concatenate([final_images,np.load(image_binary_path + "/" + i)],axis = 0)
  except:
    pass
# Out:
# training_data_64_64_100199.npy
# training_data_64_64_100299.npy
# training_data_64_64_100399.npy
# training_data_64_64_100499.npy
# training_data_64_64_100599.npy
# training_data_64_64_100699.npy
# training_data_64_64_100799.npy
# training_data_64_64_100899.npy
# training_data_64_64_100999.npy
# training_data_64_64_101099.npy
# training_data_64_64_101199.npy
# training_data_64_64_101299.npy
# training_data_64_64_101399.npy
# training_data_64_64_101499.npy
# training_data_64_64_101599.npy
# training_data_64_64_101699.npy
# training_data_64_64_101799.npy
# training_data_64_64_101899.npy
# training_data_64_64_101999.npy
# training_data_64_64_102099.npy
# training_data_64_64_102199.npy
# training_data_64_64_102299.npy
# training_data_64_64_102399.npy
# training_data_64_64_102499.npy
# training_data_64_64_102599.npy
# training_data_64_64_102699.npy
# training_data_64_64_102799.npy
# training_data_64_64_102899.npy
# training_data_64_64_102999.npy
# training_data_64_64_103099.npy
# training_data_64_64_103199.npy
# training_data_64_64_103299.npy
# training_data_64_64_103399.npy
# training_data_64_64_103499.npy
# training_data_64_64_103599.npy
# training_data_64_64_103699.npy
# training_data_64_64_103799.npy
# training_data_64_64_103899.npy
# training_data_64_64_103999.npy
# training_data_64_64_104099.npy
# training_data_64_64_104199.npy
# training_data_64_64_104299.npy
# training_data_64_64_104399.npy
# training_data_64_64_104499.npy
# training_data_64_64_104599.npy
# training_data_64_64_104699.npy
# training_data_64_64_104799.npy
# training_data_64_64_104899.npy
# training_data_64_64_104999.npy
# training_data_64_64_105099.npy
# training_data_64_64_105199.npy
# training_data_64_64_105299.npy
# training_data_64_64_105399.npy
# training_data_64_64_105499.npy
# training_data_64_64_105599.npy
# training_data_64_64_105699.npy
# training_data_64_64_105799.npy
# training_data_64_64_105899.npy
# training_data_64_64_105999.npy
# training_data_64_64_106099.npy
# training_data_64_64_106199.npy
# training_data_64_64_106299.npy
# training_data_64_64_106399.npy
# training_data_64_64_106499.npy
# training_data_64_64_106599.npy
# training_data_64_64_106699.npy
# training_data_64_64_106799.npy
# training_data_64_64_106899.npy
# training_data_64_64_106999.npy
# training_data_64_64_107099.npy
# training_data_64_64_107199.npy
# training_data_64_64_107299.npy
# training_data_64_64_107399.npy
# training_data_64_64_107499.npy
# training_data_64_64_107599.npy
# training_data_64_64_107699.npy
# training_data_64_64_107799.npy
# training_data_64_64_107899.npy
# training_data_64_64_107999.npy
# training_data_64_64_108099.npy

# %%
final_images.shape
# Out:
# (8100, 64, 64, 3)

# %%
df_captions = pd.read_csv("/content/drive/MyDrive/package stuff/Package/flowers_data/flowers/text_c10/captions.csv")

# %%
df_captions.head()
# Out:
#                                             captions
# 0  prominent purple stigma,petals are white inc olor
# 1  this flower is blue and green in color, with p...
# 2  outer petals are green in color and klarger,in...
# 3  there are several shapes, sizes, and colors of...
# 4  the stamen are towering over the stigma which ...

# %%
captions = list(df_captions.captions)

# %%
len(captions)
# Out:
# 8100

# %% [markdown]
# Saved images separately for testing

# %%
save_images_captions = captions[:28].copy()
save_images_embeddings = np.copy(caption_embeddings[:28])
save_images_npy = np.copy(final_images[:28])

# %%
caption_embeddings = caption_embeddings[:final_images.shape[0]]

# %%
caption_embeddings.shape
# Out:
# (8100, 300)

# %% [markdown]
# Shuffling the data

# %%
p = np.random.permutation(len(final_images))

# %%
final_images_shuffled = final_images[p]
final_embeddings_shuffled = caption_embeddings[p]

# %%
final_images_shuffled.shape
# Out:
# (8100, 64, 64, 3)

# %%
final_embeddings_shuffled.shape
# Out:
# (8100, 300)

# %%
# Batch and shuffle the data
# train_dataset = tf.data.Dataset.from_tensor_slices(training_data) \
#     .shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
train_dataset = tf.data.Dataset.from_tensor_slices({'images': final_images,
                                                    'embeddings': caption_embeddings}).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# ## Data Modeling

# %% [markdown]
# Defining the Generator and Discriminator

# %%
def build_generator_func(seed_size,embedding_size, channels):
  input_seed = Input(shape=seed_size)
  input_embed = Input(shape = embedding_size)
  d0 = Dense(128)(input_embed)
  leaky0 = LeakyReLU(alpha=0.2)(d0)

  merge = Concatenate()([input_seed, leaky0])

  d1 = Dense(4*4*256,activation="relu")(merge)
  reshape = Reshape((4,4,256))(d1)

  upSamp1 = UpSampling2D()(reshape)
  conv2d1 = Conv2DTranspose(256,kernel_size=5,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(upSamp1)
  batchNorm1 = BatchNormalization(momentum=0.8)(conv2d1)
  leaky1 = LeakyReLU(alpha=0.2)(batchNorm1)

  upSamp2 = UpSampling2D()(leaky1)
  conv2d2 = Conv2DTranspose(256,kernel_size=5,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(upSamp2)
  batchNorm2 = BatchNormalization(momentum=0.8)(conv2d2)
  leaky2 = LeakyReLU(alpha=0.2)(batchNorm2)

  upSamp3 = UpSampling2D()(leaky2)
  conv2d3 = Conv2DTranspose(128,kernel_size=4,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(upSamp3)
  batchNorm3 = BatchNormalization(momentum=0.8)(conv2d3)
  leaky3 = LeakyReLU(alpha=0.2)(batchNorm3)

  upSamp4 = UpSampling2D(size=(GENERATE_RES,GENERATE_RES))(leaky3)
  conv2d4 = Conv2DTranspose(128,kernel_size=4,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(upSamp4)
  batchNorm4 = BatchNormalization(momentum=0.8)(conv2d4)
  leaky4 = LeakyReLU(alpha=0.2)(batchNorm4)

  outputConv = Conv2DTranspose(channels,kernel_size=3,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(leaky4)
  outputActi = Activation("tanh")(outputConv)

  model = Model(inputs=[input_seed,input_embed], outputs=outputActi)
  return model

def build_discriminator_func(image_shape, embedding_size):
  input_shape = Input(shape=image_shape)
  input_embed = Input(shape=embedding_size)

  conv2d1 = Conv2D(32,kernel_size=4,strides=2,input_shape=image_shape,padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(input_shape)
  leaky1 = LeakyReLU(alpha=0.2)(conv2d1)

  drop2 = Dropout(0.25)(leaky1)
  conv2d2 = Conv2D(64, kernel_size=4, strides=2, padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(drop2)
  # zero2 = ZeroPadding2D(padding=((0,1),(0,1)))(conv2d2)
  batchNorm2 = BatchNormalization(momentum=0.8)(conv2d2)
  leaky2 = LeakyReLU(alpha=0.2)(batchNorm2)

  drop3 = Dropout(0.25)(leaky2)
  conv2d3 = Conv2D(128, kernel_size=4, strides=2, padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(drop3)
  batchNorm3 = BatchNormalization(momentum=0.8)(conv2d3)
  leaky3 = LeakyReLU(alpha=0.2)(batchNorm3)

  drop4 = Dropout(0.25)(leaky3)
  conv2d4 = Conv2D(256, kernel_size=4, strides=2, padding="same",kernel_initializer=initializers.RandomNormal(stddev=0.02))(drop4)
  batchNorm4 = BatchNormalization(momentum=0.8)(conv2d4)
  leaky4 = LeakyReLU(alpha=0.2)(batchNorm4)

  dense_embed = Dense(128,kernel_initializer=initializers.RandomNormal(stddev=0.02))(input_embed)
  leaky_embed = LeakyReLU(alpha=0.2)(dense_embed)
  reshape_embed = Reshape((4,4,8))(leaky_embed)
  merge_embed = Concatenate()([leaky4, reshape_embed])

  drop5 = Dropout(0.25)(merge_embed)
  conv2d5 = Conv2D(512, kernel_size=4,kernel_initializer=initializers.RandomNormal(stddev=0.02))(drop5)
  batchNorm5 = BatchNormalization(momentum=0.8)(conv2d5)
  leaky5 = LeakyReLU(alpha=0.2)(batchNorm5)

  drop6 = Dropout(0.25)(leaky5)
  flatten = Flatten()(drop6)
  output = Dense(1,activation="sigmoid")(flatten)

  model = Model(inputs=[input_shape,input_embed], outputs=output)
  return model

# %% [markdown]
# Function to save image samples generated

# %%
def save_images(cnt,noise,embeds):
  image_array = np.full(( 
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3), 
      255, dtype=np.uint8)

  generated_images = generator.predict((noise,embeds))

  generated_images = 0.5 * generated_images + 0.5

  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] \
            = generated_images[image_count] * 255
        image_count += 1

          
  output_path = "/content/drive/MyDrive/package stuff/Package/flowers_data/flowers/output"
  if not os.path.exists(output_path):
    os.makedirs(output_path)

  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)

# %%
# Initlializing a generator
generator = build_generator_func(SEED_SIZE,EMBEDDING_SIZE, IMAGE_CHANNELS)
try:
  generator.load_weights("/content/drive/MyDrive/package stuff/Package/flowers_data/flowers/model/text_to_image_generator_cub_character.h5")
except:
  print("No loading previous model")
# Out:
# No loading previous model

# %%
# Sample output from the Generator
noise = tf.random.normal([1, 100])
generated_image = generator((noise,caption_embeddings[5].reshape(1,300)), training=False)

plt.imshow(generated_image[0, :, :, 0])

# %%
# Initlializing a discriminator
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)

discriminator = build_discriminator_func(image_shape,EMBEDDING_SIZE)
try:
  discriminator.load_weights((os.path.join(MODEL_PATH,"text_to_image_disc_cub_character.h5")))
except:
  print("No loading previous model")
# Out:
# No loading previous model

# %%
decision = discriminator((generated_image,caption_embeddings[5].reshape(1,300)))
print(decision)
# Out:
# tf.Tensor([[0.50420207]], shape=(1, 1), dtype=float32)

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discriminator_loss(real_image_real_text, fake_image_real_text, real_image_fake_text):
    real_loss = cross_entropy(tf.random.uniform(real_image_real_text.shape,0.8,1.0), real_image_real_text)
    fake_loss = (cross_entropy(tf.random.uniform(fake_image_real_text.shape,0.0,0.2), fake_image_real_text) + 
                 cross_entropy(tf.random.uniform(real_image_fake_text.shape,0.0,0.2), real_image_fake_text))/2

    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
# lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate=2e-4,
#     decay_steps=100,
#     decay_rate=0.5)
generator_optimizer = tf.keras.optimizers.Adam(learning_rate=2.0e-4,beta_1 = 0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate=2.0e-4,beta_1 = 0.5)

# %% [markdown]
# ## Training

# %%
# Notice the use of `tf.function`
# This annotation causes the function to be "compiled".
@tf.function
def train_step(images,captions,fake_captions):
  seed = tf.random.normal([BATCH_SIZE, SEED_SIZE],dtype=tf.float32)

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator((seed,captions), training=True)
    real_image_real_text = discriminator((images,captions), training=True)
    real_image_fake_text = discriminator((images,fake_captions), training=True)
    fake_image_real_text = discriminator((generated_images,captions), training=True)

    gen_loss = generator_loss(fake_image_real_text)
    disc_loss = discriminator_loss(real_image_real_text, fake_image_real_text, real_image_fake_text)
    # print(gen_loss)
    # print(disc_loss)

    gradients_of_generator = gen_tape.gradient(\
        gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(\
        disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(
        gradients_of_discriminator, 
        discriminator.trainable_variables))
  return gen_loss,disc_loss

# %%
# Function that executes trianing process
def train(train_dataset, epochs):
  fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS, 
                                       SEED_SIZE))
  fixed_embed = save_images_embeddings

  start = time.time()

  for epoch in range(epochs):
    print("epoch start...")
    epoch_start = time.time()

    gen_loss_list = []
    disc_loss_list = []

    for batch in train_dataset[:-1]:
      # train_batch = training_data[BATCH_SIZE*image_batch : BATCH_SIZE*image_batch + BATCH_SIZE]
      # caption_batch = captions[BATCH_SIZE*image_batch : BATCH_SIZE*image_batch + BATCH_SIZE]
      train_batch = batch['images']
      caption_batch = batch['embeddings']
      
      fake_caption_batch = np.copy(caption_batch)
      np.random.shuffle(fake_caption_batch)
      
      t = train_step(train_batch,caption_batch,fake_caption_batch)
      # print(t)
      gen_loss_list.append(t[0])
      disc_loss_list.append(t[1])
      # if image_batch%50 == 0:
      #   print(image_batch)
      # print("here")
    print("now")
    g_loss = sum(gen_loss_list) / len(gen_loss_list)
    d_loss = sum(disc_loss_list) / len(disc_loss_list)

    epoch_elapsed = time.time()-epoch_start
    print(f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss}, {hms_string(epoch_elapsed)}')
    save_images(epoch,fixed_seed,fixed_embed)
    
    generator.save(os.path.join(MODEL_PATH,"text_to_image_generator_cub_character.h5"))
    discriminator.save(os.path.join(MODEL_PATH,"text_to_image_disc_cub_character.h5"))
    print("model saved")

  elapsed = time.time()-start
  print ('Training time:', hms_string(elapsed))

# %%
train(list(train_dataset.as_numpy_iterator()), 500)
# Out:
# epoch start...
# now
# Epoch 1, gen loss=0.8042378425598145,disc loss=1.5411397218704224, 0:00:39.38
# 1/1 [==============================] - 1s 668ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 2, gen loss=0.767966091632843,disc loss=1.475882887840271, 0:00:26.09
# 1/1 [==============================] - 0s 21ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 3, gen loss=0.756489634513855,disc loss=1.4433107376098633, 0:00:26.41
# 1/1 [==============================] - 0s 21ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 4, gen loss=0.7251661419868469,disc loss=1.4301210641860962, 0:00:26.71
# 1/1 [==============================] - 0s 22ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 5, gen loss=0.7257819771766663,disc loss=1.4230808019638062, 0:00:26.96
# 1/1 [==============================] - 0s 20ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 6, gen loss=0.7196142077445984,disc loss=1.424440622329712, 0:00:27.14
# 1/1 [==============================] - 0s 20ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 7, gen loss=0.7210082411766052,disc loss=1.414467215538025, 0:00:27.31
# 1/1 [==============================] - 0s 21ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 8, gen loss=0.7223443984985352,disc loss=1.4107998609542847, 0:00:27.40
# 1/1 [==============================] - 0s 21ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 9, gen loss=0.7226243019104004,disc loss=1.4037268161773682, 0:00:27.62
# 1/1 [==============================] - 0s 30ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 10, gen loss=0.7236652970314026,disc loss=1.3998404741287231, 0:00:27.79
# 1/1 [==============================] - 0s 33ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 11, gen loss=0.7293289303779602,disc loss=1.4008057117462158, 0:00:27.84
# 1/1 [==============================] - 0s 20ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 12, gen loss=0.7217816114425659,disc loss=1.3951359987258911, 0:00:27.88
# 1/1 [==============================] - 0s 21ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch
ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 440, gen loss=1.5365186929702759,disc loss=1.0639276504516602, 0:00:27.91
# 1/1 [==============================] - 0s 21ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 441, gen loss=1.5180013179779053,disc loss=1.0606844425201416, 0:00:27.95
# 1/1 [==============================] - 0s 22ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 442, gen loss=1.523490309715271,disc loss=1.0582069158554077, 0:00:27.94
# 1/1 [==============================] - 0s 21ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 443, gen loss=1.4961214065551758,disc loss=1.0649250745773315, 0:00:27.90
# 1/1 [==============================] - 0s 20ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 444, gen loss=1.5779788494110107,disc loss=1.054581642150879, 0:00:27.87
# 1/1 [==============================] - 0s 28ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 445, gen loss=1.5206935405731201,disc loss=1.0622365474700928, 0:00:27.90
# 1/1 [==============================] - 0s 20ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 446, gen loss=1.4718427658081055,disc loss=1.0852210521697998, 0:00:27.95
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 447, gen loss=1.5121660232543945,disc loss=1.0651228427886963, 0:00:27.96
# 1/1 [==============================] - 0s 20ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 448, gen loss=1.5319429636001587,disc loss=1.0614405870437622, 0:00:27.97
# 1/1 [==============================] - 0s 20ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 449, gen loss=1.5384958982467651,disc loss=1.0519553422927856, 0:00:27.96
# 1/1 [==============================] - 0s 31ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 450, gen loss=1.5866296291351318,disc loss=1.0537978410720825, 0:00:27.96
# 1/1 [==============================] - 0s 20ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 451, gen loss=1.4756386280059814,disc loss=1.0647331476211548, 0:00:27.99
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...
# now
# Epoch 452, gen loss=1.6230720281600952,disc loss=1.0497024059295654, 0:00:27.94
# 1/1 [==============================] - 0s 20ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# model saved
# epoch start...

# %% [markdown]
# ## Results

# %%
save_images_embeddings.shape
# Out:
# (28, 300)

# %%
# Printing the captions
save_images_captions
# Out:
# ['prominent purple stigma , petals are white inc olor',
#  'this flower is blue and green in color ,  with petals that are oval shaped . ',
#  'outer petals are green in color and klarger , inner petals are needle shaped',
#  'there are several shapes ,  sizes ,  and colors of petals on this complex flower . ',
#  'the stamen are towering over the stigma which cannot be seen . ',
#  'this flower is white and purple in color ,  with petals that are oval shaped . ',
#  'the petals of this flower are green with a long stigma',
#  'the blossom has a layer of rounded purple and white petals topped by a layer of fringed purple petals . ',
#  'this flower is purple and yellow in color ,  with petals that are oval shaped . ',
#  'the petals on this flower are white with an elaborate pistil . ',
#  'this flower has petals that are pink with stringy white stamen',
#  'this flower has star shaped white petals as its main feature . ',
#  'lower petals are white in color , and larger in size , inner petals are purple in clor',
#  'this flower has petals in the shape of a circle and are purple and stringy',
#  'a unique looking flower that has multiple colors and long petals',
#  'this flower is white and purple in color ,  with petals that are oval shaped . ',
#  'this flower is white in color ,  with petals that are oval shaped . ',
#  'this flower has thick star shaped maroon petals as its main feature . ',
#  'this flower has petals that are white with purple stringy stamen',
#  'the pistil is white and is very noticeable ,  and the petals are purple . ',
#  'purple flower with curvy string - like petals and a group of large yellow stamen in the center . ',
#  'this flower has an elaborate golden stamen and two different types of purple petals . ',
#  'flower with white long white petals and very long purple stamen',
#  'this flower is blue and white in color ,  with petals that are oval shaped . ',
#  'leaves are green in color , outer petals are white green in color',
#  'the petals of the flower are pink in color and have filaments that are pink in color . ',
#  'this is a purple flower with long purple anthers on it . ',
#  'this is a strange flower with purple petals and a white stigma . ']

# %%
def test_image(text,num):
  test_embeddings = np.zeros((1,300),dtype=np.float32)

  x = text.lower()
  x = x.replace(" ","")
  count = 0
  for t in x:
    try:
      test_embeddings[0] += glove_embeddings[t]
      count += 1
    except:
      print(t)
      pass
  test_embeddings[0] /= count
  test_embeddings =  np.repeat(test_embeddings,[28],axis=0)
  noise = tf.random.normal([28, 100])
  save_images(num,noise,test_embeddings)

# %%
test_image("this flower is purple in color with oval shaped petals",1)

# %%
import IPython
IPython.display.Image('/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/output_64_character_extended/train-1.png')

# %%
test_image("this flower is yellow in color with oval shaped petals",2)

# %%
import IPython
IPython.display.Image('/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/output_64_character_extended/train-2.png')

# %%
test_image("this flower is pink in color with oval shaped petals",3)

# %%
import IPython
IPython.display.Image('/content/drive/Shareddrives/D4NLP Project/flowers data/flowers/output_64_character_extended/train-3.png')

# %% [markdown]
# #Installing LIB

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 34.3 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.7)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 57.2 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 25.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.3 tokenizers-0.13.2 transformers-4.27.4

# %%
# !pip install diffusers[transformers]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting diffusers[transformers]
#   Downloading diffusers-0.14.0-py3-none-any.whl (737 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.4/737.4 KB 13.8 MB/s eta 0:00:00
# WARNING: diffusers 0.14.0 does not provide the extra 'transformers'
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from diffusers[transformers]) (1.22.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from diffusers[transformers]) (8.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from diffusers[transformers]) (3.10.7)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from diffusers[transformers]) (2022.10.31)
# Requirement already satisfied: huggingface-hub>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from diffusers[transformers]) (0.13.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from diffusers[transformers]) (2.27.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.9/dist-packages (from diffusers[transformers]) (6.1.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.10.0->diffusers[transformers]) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.10.0->diffusers[transformers]) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.10.0->diffusers[transformers]) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.10.0->diffusers[transformers]) (23.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata->diffusers[transformers]) (3.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers[transformers]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers[transformers]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers[transformers]) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers[transformers]) (1.26.15)
# Installing collected packages: diffusers
# Successfully installed diffusers-0.14.0

# %%
# !pip install streamlit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting streamlit
#   Downloading streamlit-1.20.0-py2.py3-none-any.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 66.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas<2,>=0.25 in /usr/local/lib/python3.9/dist-packages (from streamlit) (1.4.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.9/dist-packages (from streamlit) (13.3.3)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging>=14.1 in /usr/local/lib/python3.9/dist-packages (from streamlit) (23.0)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.9/dist-packages (from streamlit) (4.3)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 96.7 MB/s eta 0:00:00
# Collecting semver
#   Downloading semver-3.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.9/dist-packages (from streamlit) (6.1.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from streamlit) (8.4.0)
# Requirement already satisfied: altair<5,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from streamlit) (1.22.4)
# Requirement already satisfied: protobuf<4,>=3.12 in /usr/local/lib/python3.9/dist-packages (from streamlit) (3.20.3)
# Collecting watchdog
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 KB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=4.0 in /usr/local/lib/python3.9/dist-packages (from streamlit) (9.0.0)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 24.3 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from streamlit) (8.1.3)
# Requirement already satisfied: requests>=2.4 in /usr/local/lib/python3.9/dist-packages (from streamlit) (2.27.1)
# Collecting blinker>=1.0.0
#   Downloading blinker-1.6-py3-none-any.whl (13 kB)
# Requirement already satisfied: toml in /usr/local/lib/python3.9/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.9/dist-packages (from streamlit) (5.3.0)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 KB 21.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from streamlit) (2.8.2)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.9/dist-packages (from streamlit) (6.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.9/dist-packages (from streamlit) (4.5.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit) (4.3.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit) (0.12.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit) (3.1.2)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=1.4->streamlit) (3.15.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas<2,>=0.25->streamlit) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.4->streamlit) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.4->streamlit) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.4->streamlit) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.4->streamlit) (1.26.15)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich>=10.11.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich>=10.11.0->streamlit) (2.14.0)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.9/dist-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.9/dist-packages (from validators>=0.2->streamlit) (4.4.2)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->altair<5,>=3.2.0->streamlit) (2.1.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit) (0.1.2)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.9/dist-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit) (2023.3)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=3c8b7e51ebdeecd5f73e9a713942fa6cf774ea037e077ba93757b52ad582c78e
#   Stored in directory: /root/.cache/pip/wheels/2d/f0/a8/1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
# Successfully built validators
# Installing collected packages: watchdog, validators, smmap, semver, pympler, blinker, pydeck, gitdb, gitpython, streamlit
# Successfully installed blinker-1.6 gitdb-4.0.10 gitpython-3.1.31 pydeck-0.8.0 pympler-1.0.1 semver-3.0.0 smmap-5.0.0 streamlit-1.20.0 validators-0.20.0 watchdog-3.0.0

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# --2023-04-05 03:00:11--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 54.161.241.46, 54.237.133.81, 52.202.168.65, ...
# Connecting to bin.equinox.io (bin.equinox.io)|54.161.241.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13921656 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.28M  16.4MB/s    in 0.8s
#
# 2023-04-05 03:00:13 (16.4 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13921656/13921656]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
import transformers
from diffusers import StableDiffusionPipeline
import torch
model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")
# Out:
# Downloading (…)ain/model_index.json:   0%|          | 0.00/543 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Downloading (…)cheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# Downloading (…)_encoder/config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# Downloading (…)tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading (…)_checker/config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading (…)rocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading (…)on_pytorch_model.bin:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# Downloading (…)819/unet/config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading (…)d819/vae/config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# Downloading (…)on_pytorch_model.bin:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# /usr/local/lib/python3.9/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(

# %% [markdown]
# # UI

# %%
prompt = "flower pink oval shaped petals"

image = pipe(prompt).images[0]  

image = image.resize((64,64))

image.save("img1.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
from matplotlib import pyplot as plt
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
prompt = "oval shaped petals flowers which is pink in color"

image = pipe(prompt).images[0]  
image = image.resize((64,64))

image.save("img2.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
from matplotlib import pyplot as plt
plt.imshow(image)
#plt.axis("off")
plt.show()
